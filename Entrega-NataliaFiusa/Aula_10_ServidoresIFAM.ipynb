# %% [markdown]
# <a href="https://colab.research.google.com/github/nataliafiusa/lia1_2024_1/blob/main/Entrega-NataliaFiusa/Aula_10_ServidoresIFAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Ciência de Dados - Servidores do Instituto Federal do Amapá** 📘
#
#
# ---
#
#
# Este dataset da relação de servidores públicos do Instituto Federal do Amapá, apresenta uma relação de docentes substitutos e docentes efetivos da instituição, contando com um corpo de docentes de 345 pessoas.
#
# **Contém 4 perguntas e 1 desafio master**

# %% [markdown]
# **Importando as bibliotecas necessárias**

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %% [markdown]
# **Carregando os dados**

# %%
# Carrega o dataset
df_ss = pd.read_csv('/content/docentes.csv', encoding='latin1')

# %%
# Shape
df_ss.shape
# Out:
# (345, 6)

# %%
# Amostra dos dados
df_ss.head()
# Out:
#    MATRICULA                              SERVIDOR  \
# 0    3252310             Aldineia Pereira da Silva
# 1    1148956                    Alex Santiago Nina
# 2    3251934             Ana Luzia Ferreira Farias
# 3    1192830               Andre Bacelar Rodrigues
# 4    2353041  Antonio Joao Cordeiro Barbosa Junior
#
#                                        CARGO EMPREGO  \
# 0  PROF ENS BAS TEC TECNOLOGICO-SUBSTITUTO (CMEBT...
# 1  PROF ENS BAS TEC TECNOLOGICO-SUBSTITUTO (CMEBT...
# 2  PROF ENS BAS TEC TECNOLOGICO-SUBSTITUTO (CMEBT...
# 3  PROF ENS BAS TEC TECNOLOGICO-SUBSTITUTO (CMEBT...
# 4  PROF ENS BAS TEC TECNOLOGICO-SUBSTITUTO (CMEBT...
#
#   DATA INICIO EXERCICIO NA INSTITUICAO DATA INICIO SERVICO PUBLICO  \
# 0                           27/09/2021                  27/09/2021
# 1                           16/05/2022                  16/05/2022
# 2                           14/09/2021                  14/09/2021
# ...

# %%
# Amostra dos dados
df_ss.tail()
# Out:
#      MATRICULA                        SERVIDOR  \
# 340    1385054  Welber Carlos Andrade da Silva
# 341    1852758           Whitney Santos Cabral
# 342    1837945       Willians Lopes de Almeida
# 343    2143716          Wladson da Silva Leite
# 344    1808635       Zigmundo Antonio de Paula
#
#                                          CARGO EMPREGO  \
# 340  PROFESSOR ENS BASICO TECN TECNOLOGICO (CMEBT) ...
# 341  PROFESSOR ENS BASICO TECN TECNOLOGICO (CMEBT) ...
# 342  PROFESSOR ENS BASICO TECN TECNOLOGICO (CMEBT) ...
# 343  PROFESSOR ENS BASICO TECN TECNOLOGICO (CMEBT) ...
# 344  PROFESSOR ENS BASICO TECN TECNOLOGICO (CMEBT) ...
#
#     DATA INICIO EXERCICIO NA INSTITUICAO DATA INICIO SERVICO PUBLICO  \
# 340                           26/04/2018                  26/04/2018
# 341                           02/05/2018                  23/04/2018
# 342                           26/01/2011                  26/01/2011
# ...

# %% [markdown]
# **Análise exploratória**

# %%
# Colunas do conjunto de dados
df_ss.columns
# Out:
# Index(['MATRICULA', 'SERVIDOR', 'CARGO EMPREGO',
#        'DATA INICIO EXERCICIO NA INSTITUICAO', 'DATA INICIO SERVICO PUBLICO',
#        'DISCIPLINA INGRESSO'],
#       dtype='object')

# %%
# Verificando o tipo de dado de cada coluna
df_ss.dtypes
# Out:
# MATRICULA                                int64
# SERVIDOR                                object
# CARGO EMPREGO                           object
# DATA INICIO EXERCICIO NA INSTITUICAO    object
# DATA INICIO SERVICO PUBLICO             object
# DISCIPLINA INGRESSO                     object
# dtype: object

# %%
# Verificando se há registros duplicados
df_ss[df_ss.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID_Pedido, Data_Pedido, ID_Cliente, Segmento, Pais, Cidade, Estado, ID_Produto, Categoria, SubCategoria, Valor_Venda]
# Index: []

# %%
# Verificando de há valores ausentes
df_ss.isnull().sum()
# Out:
# MATRICULA                               0
# SERVIDOR                                0
# CARGO EMPREGO                           0
# DATA INICIO EXERCICIO NA INSTITUICAO    0
# DATA INICIO SERVICO PUBLICO             0
# DISCIPLINA INGRESSO                     0
# dtype: int64

# %% [markdown]
# ## **1. Quantos professores de Matemática há na instituição?**

# %%
# Primeiro filtramos o dataframe com os registros da categoria que desejamos
quantidade_matematica = df_ss[df_ss['DISCIPLINA INGRESSO'] == 'MATEMATICA'].shape[0]

# %%
# Agora é só mostrar o resultado da filtragem
print("Existe essa quantidade professores de Mátemática na Instituição:", quantidade_matematica)
# Out:
# Quantidade de vezes que 'Matematica' aparece na coluna 'DISCIPLINA_INGRESSO': 14

# %% [markdown]
# ## **2. Quantos professores de Matemática ingressam na instuiçao por data?**
# Apresente o resultado em um gráfico de barras.

# %%
# Disciplina específica que você deseja visualizar
disciplina_especifica = 'MATEMATICA'

# Filtrando o DataFrame para incluir apenas a disciplina específica
df_disciplina_especifica = df_ss[df_ss['DISCIPLINA INGRESSO'] == disciplina_especifica]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(df_disciplina_especifica['DATA INICIO EXERCICIO NA INSTITUICAO'], range(len(df_disciplina_especifica)), marker='o', linestyle='-')
plt.title(f'Relação entre a data de início de exercício na instituição e a disciplina {disciplina_especifica}')
plt.xlabel('Data de Início de Exercício na Instituição')
plt.ylabel(f'Contagem de Professores de {disciplina_especifica}')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **3. Quantos professores de Gestão ingressam na instuiçao por data?**
# Apresente o resultado em um gráfico de barras.

# %%
# Disciplina específica que você deseja visualizar
disciplina_especifica2 = 'GESTAO'

# Filtrando o DataFrame para incluir apenas a disciplina específica
df_disciplina_especifica2 = df_ss[df_ss['DISCIPLINA INGRESSO'] == disciplina_especifica2]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(df_disciplina_especifica2['DATA INICIO EXERCICIO NA INSTITUICAO'], range(len(df_disciplina_especifica2)), marker='o', linestyle='-')
plt.title(f'Relação entre a data de início de exercício na instituição e a disciplina {disciplina_especifica2}')
plt.xlabel('Data de Início de Exercício na Instituição')
plt.ylabel(f'Contagem de Professores de {disciplina_especifica2}')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **4. Quais são as 10 diciplinas com mais docentes?**
# Apresente o resultado em um gráfico de barras.

# %%
# Contagem do número de servidores por disciplina de ingresso
contagem_disciplina = df_ss['DISCIPLINA INGRESSO'].value_counts().head(10)

print("Os 10 objetos da classe 'DISCIPLINA INGRESSO' que contêm mais servidores:")
print(contagem_disciplina)
# Out:
# Os 10 objetos da classe 'DISCIPLINA INGRESSO' que contêm mais servidores:
# DISCIPLINA INGRESSO
# INFORMATICA         24
# GESTAO              22
# MATEMATICA         15
# MATEMATICA          14
# INGLES              14
#  PORTUGUES          14
# BIOLOGIA            13
# CONSTRUCAO CIVIL    13
# QUIMICA            12
# GEOGRAFIA           11
# Name: count, dtype: int64

# %%
# Contagem do número de servidores por disciplina de ingresso
contagem_disciplina = df_ss['DISCIPLINA INGRESSO'].value_counts().head(10)

# Plotagem do gráfico de pizza
plt.figure(figsize=(8, 8))
contagem_disciplina.plot.pie(autopct='%1.1f%%', startangle=140)
plt.title("Distribuição das 10 disciplinas de ingresso com mais servidores")
plt.ylabel('')  # Remove o rótulo do eixo y
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 141 (\x8d) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## **Desafio Master Blaster**
#
#
# ---
#
# Infelizmente o Governo Federal não tem mais dinheiro para manter tantos docentes na Instituição e pretente deixar todas as disciplicinas com 5
#
#
# *   Se atualmente a diciplina tem mais de 5 servidores, ela ficará com apens 5 docentes;
# *   Se a diciplina já tiver menos que 5 servidores, a quantidade permanecerá inalterada
#
# Quantos professores precisarão ser despedidos?

# %%
# Contagem do número de servidores por disciplina de ingresso
contagem_disciplina = df_ss['DISCIPLINA INGRESSO'].value_counts()

# Identificar as disciplinas com mais de 5 servidores
disciplinas_excedentes = contagem_disciplina[contagem_disciplina > 5].index.tolist()

# Inicializar o contador de servidores excluídos
servidores_excluidos = 0

# Iterar sobre as disciplinas excedentes
for disciplina in disciplinas_excedentes:
    # Filtrar o DataFrame para manter apenas as primeiras 5 ocorrências de cada disciplina excedente
    index_disciplina_excedente = df_ss[df_ss['DISCIPLINA INGRESSO'] == disciplina].index[5:]
    # Verificar se existem servidores a serem excluídos
    if len(index_disciplina_excedente) > 0:
        df_ss.drop(index_disciplina_excedente, inplace=True)
        # Atualizar o contador de servidores excluídos
        servidores_excluidos += len(index_disciplina_excedente)

if servidores_excluidos == 0:
    print("Não foram encontrados servidores excedentes.")
else:
    print(f"Foram excluídos {servidores_excluidos} servidores.")
# Out:
# Foram excluídos 84 servidores.
