# %% [markdown]
# <a href="https://colab.research.google.com/github/Juliana001/lia1_2024_1/blob/main/Entregas%20-%20Juliana%20Rocha/Tarefa_aula_10_04_LIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importando o necessário
import tensorflow as tf
import keras as keras
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
# Classes das imagens
nomes_classes = ['T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
# Normaliza os valores dos pixels para que os dados fiquem na mesma escala
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
# Função para exibir as imagens
def visualiza_imagens(images, labels):
    plt.figure(figsize = (10,10))
    for i in range(16):
        plt.subplot(4, 4, i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap = plt.cm.binary)
        plt.xlabel(nomes_classes[labels[i]])
    plt.show()

# %%
# Executa a função
visualiza_imagens(train_images, train_labels)

# %%
# Arquitetura do Modelo -> Feature Learning

# Cria o objeto de sequência de camadas - do Keras
modelo_lia = models.Sequential()

# Adiciona a primeira camada de convolução e max pooling (camada de entrada)
modelo_lia.add(layers.Conv2D(28, (3, 3), activation = 'relu', input_shape = (28, 28, 1)))
modelo_lia.add(layers.MaxPooling2D((2, 2)))

# Adiciona a segunda camada de convolução e max pooling (camada intermediária)
modelo_lia.add(layers.Conv2D(64, (3, 3), activation = 'relu'))
modelo_lia.add(layers.MaxPooling2D((2, 2)))

# Adiciona a terceira camada de convolução e max pooling (camada intermediária)
modelo_lia.add(layers.Conv2D(64, (3, 3), activation = 'relu'))
modelo_lia.add(layers.MaxPooling2D((2, 2)))

# %%
# Adicionar camadas de classificação - Converte para um vetor - flatten
modelo_lia.add(layers.Flatten())
modelo_lia.add(layers.Dense(64, activation = 'relu'))
modelo_lia.add(layers.Dense(10, activation = 'softmax'))

# %%
# Compilação do modelo
modelo_lia.compile(optimizer = 'adam',
                   loss = 'sparse_categorical_crossentropy',
                   metrics = ['accuracy'])

# adam - é um algoritmo de aprendizagem tipo backpropagation!
# loss - função de erro. Isso se resume a uma otimização função matemática!
# metrics - medir o sucesso!

# %%
# Executando o treinamento
# %%time
history = modelo_lia.fit(train_images,
                         train_labels,
                         epochs = 10,
                         validation_data = (test_images, test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 13s 4ms/step - loss: 0.6002 - accuracy: 0.7803 - val_loss: 0.4699 - val_accuracy: 0.8318
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4106 - accuracy: 0.8502 - val_loss: 0.3885 - val_accuracy: 0.8582
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3545 - accuracy: 0.8703 - val_loss: 0.3533 - val_accuracy: 0.8720
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3175 - accuracy: 0.8834 - val_loss: 0.3389 - val_accuracy: 0.8760
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2887 - accuracy: 0.8931 - val_loss: 0.3481 - val_accuracy: 0.8734
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2686 - accuracy: 0.9016 - val_loss: 0.3222 - val_accuracy: 0.8849
# Epoch 7/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2478 - accuracy: 0.9099 - val_loss: 0.3049 - val_accuracy: 0.8895
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2325 - accuracy: 0.9150 - val_loss: 0.3249 - val_accuracy: 0.8914
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2172 - accuracy: 0.9202 - val_loss: 0.3337 - val_accuracy: 0.8864
# Epoch 10/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2080 - accuracy: 0.9227 - val_loss: 0.3048 - val_accuracy: 0.8941
# CPU times: user 1min 21s, sys: 5.59 s, total: 1min 27s
# Wall time: 1min 20s

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Carrega uma nova imagem
nova_imagem = Image.open("/content/drive/MyDrive/tarefa dia 08/imagem002.png")

# Redimensiona para 32x32 pixels
nova_imagem = nova_imagem.resize((28, 28))

# Exibir a imagem
plt.figure(figsize = (1,1))
plt.imshow(nova_imagem, cmap='gray')
plt.imshow(nova_imagem)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
# Converte a imagem para um array NumPy e normaliza
nova_imagem_array = np.array(nova_imagem) / 255.0

# %%
# Expande a dimensão do array para que ele tenha o formato (1, 32, 32, 3)
#nova_imagem_array = np.expand_dims(nova_imagem_array, axis = 0)

# %%
#nova_imagem_array = np.expand_dims(nova_imagem_array, axis=0)
#nova_imagem_array = np.expand_dims(nova_imagem_array, axis=-1)

# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Carrega uma nova imagem
nova_imagem = Image.open("/content/drive/MyDrive/tarefa dia 08/imagem003.png")

# Redimensiona para 28x28 pixels
nova_imagem = nova_imagem.resize((28, 28))

# Exibir a imagem
plt.figure(figsize=(1, 1))
plt.imshow(nova_imagem, cmap='gray')
plt.xticks([])
plt.yticks([])
plt.show()

# Converte a imagem para um array NumPy e normaliza
nova_imagem_array = np.array(nova_imagem) / 255.0

# Garante que a imagem tenha uma única dimensão de canal (escala de cinza)
if len(nova_imagem_array.shape) == 3:
    nova_imagem_array = np.mean(nova_imagem_array, axis=2)

# Adiciona uma dimensão para corresponder ao formato esperado pelo modelo
imagem_para_modelo = nova_imagem_array.reshape(1, 28, 28, 1)

# Faz a previsão
previsoes = modelo_lia.predict(imagem_para_modelo)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 1/1 [==============================] - 0s 272ms/step

# %%
print(previsoes)
# Out:
# [[6.2033501e-03 1.3795231e-03 2.6174320e-02 2.8975632e-03 2.7578927e-03
#   7.1759871e-04 2.1090351e-02 2.0216629e-04 9.3730849e-01 1.2687268e-03]]

# %%
# Obtém a classe com maior probabilidade e o nome da classe
classe_prevista = np.argmax(previsoes)
nome_classe_prevista = nomes_classes[classe_prevista]

# %%
print("A nova imagem foi classificada como:", nome_classe_prevista)
# Out:
# A nova imagem foi classificada como: Bag
