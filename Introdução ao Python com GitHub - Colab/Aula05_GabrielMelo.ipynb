# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielmds0/lia1_2024_1/blob/main/Introdu%C3%A7%C3%A3o%20ao%20Python%20com%20GitHub%20-%20Colab/Aula05_GabrielMelo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <hr>
# <div class="container">
#     <img src='https://github.com/scadriano/datascience/blob/main/datascienceintroduce/header.png?raw=true' align='left' width='180'  height='200' />
# </div>
#
# <h1>Laboratório de Inovação e Automação 1 (LIA 1)</h1>
# 	<div>  2024/1 | 24M34 | Sala 200 CAE</ </div>
# <hr>
#
# <h2> Introdução ao Python com Github - Colab </h2>
# Notebook desenvolvido por: <a href="http://lattes.cnpq.br/1346824250595330">Prof. Dr. Adriano C. Santana</a>
#
# <hr>

# %% [markdown]
# https://codeshare.io/Mkj6r3

# %%
# Confirmar a versão da Linguagem Python instalada
from platform import python_version
print(f'A versão da linguagem Python usada neste projeto é a {python_version()}!')
#python_version
# Out:
# A versão da linguagem Python usada neste projeto é a 3.10.12!

# %%
# Verificar se o Python está funcionando
print('Bye bye, World!')
# Out:
# Bye bye, World!

# %% [markdown]
# ### Lendo Arquivos || Local

# %%
a1 = open("/content/samples/arquivo1.txt", "r")
print(a1.read())
# Out:
# Seja bem-vindo em LIA1 - 2024/1 - 01/04!

# %% [markdown]
# ### Gravando Dados

# %%
a2 = open("/content/samples/arquivo2.txt", "w")
a2.write("Aprendendo Python em 2024/1 ao som de um cortador de grama!")
# Out:
# 59

# %%
a2 = open("/content/samples/arquivo2.txt", "r")
print(a2.read())
# Out:
# Aprendendo Python em 2024/1 ao som de um cortador de grama!

# %% [markdown]
# ### Criando, Gravando e Lendo Arquivos

# %%
file1 = open("/content/samples/TesteGravacao.txt", "r")
print(file1.read())
# Out:
# Teste de gravação na criação de arquivos!

# %%
import os.path

save_path = '/content/samples/'

name_of_file = input("Qual o nome do arquivo: ")

completeName = os.path.join(save_path, name_of_file+".txt")

file1 = open(completeName, "w")

toFile = input("Escreva o conteudo do seu arquivo:")

file1.write(toFile)

file1.close()
# Out:
# Qual o nome do arquivo: TesteGravacao
# Escreva o conteudo do seu arquivo:Teste de gravação na criação de arquivos!

# %% [markdown]
# ### Manipulando DataSets

# %%
# Importando pandas
import pandas as pd

# %%
# Lendo o arquivo e transformando em csv
df = pd.read_csv ('https://raw.githubusercontent.com/scadriano/lia1_2024_1/main/Introdu%C3%A7%C3%A3o%20ao%20Python%20com%20GitHub%20-%20Colab/hospital.txt', sep=',', index_col=None)

# %%
df
# Out:
#       Id     Nome  Idade Sexo  Peso       Manchas  Temp  Internação Estado  \
# 0   4201     João     55    M  90.0  Concentradas  38.0           2     SP
# 1   3217    Maria     56    F  91.0  Inexistentes  39.5           4     MG
# 2   4039     Luiz     49    M  92.0    Espalhadas  38.0           2     RS
# 3   1920     José     57    M  93.0  Inexistentes  38.5           2     MG
# 4   4340  Cláudia     21    F  52.0     Uniformes  37.6           1     PE
# 5   2301      Ana     58    F  94.0  Inexistentes  38.0           3     RJ
# 6   1322    Marta     19    F  87.0    Espalhadas  39.0           3     AM
# 7   3027    Paulo     34    M  67.0     Uniformes  38.4           2     GO
# 8   3546  Roberto     44    M   NaN     Uniformes  37.6           1     PE
# 9   6754   Lorena     33    F  72.0  Inexistentes  38.0           3     RJ
# 10  1735    Pedro     13    M  87.0    Espalhadas   6.0           4     AM
# ...

# %%
display(df.head(5))
# Out:
#      Id     Nome  Idade Sexo  Peso       Manchas  Temp  Internação Estado  \
# 0  4201     João     55    M  90.0  Concentradas  38.0           2     SP
# 1  3217    Maria     56    F  91.0  Inexistentes  39.5           4     MG
# 2  4039     Luiz     49    M  92.0    Espalhadas  38.0           2     RS
# 3  1920     José     57    M  93.0  Inexistentes  38.5           2     MG
# 4  4340  Cláudia     21    F  52.0     Uniformes  37.6           1     PE
#
#         Time Diagnóstico
# 0  Palmeiras      Doente
# 1   Cruzeiro      Doente
# 2     Grêmio    Saudável
# 3   Atlético      Doente
# 4      Sport    Saudável

# %%
display(df.head(10))
# Out:
#      Id     Nome  Idade Sexo  Peso       Manchas  Temp  Internação Estado  \
# 0  4201     João     55    M  90.0  Concentradas  38.0           2     SP
# 1  3217    Maria     56    F  91.0  Inexistentes  39.5           4     MG
# 2  4039     Luiz     49    M  92.0    Espalhadas  38.0           2     RS
# 3  1920     José     57    M  93.0  Inexistentes  38.5           2     MG
# 4  4340  Cláudia     21    F  52.0     Uniformes  37.6           1     PE
# 5  2301      Ana     58    F  94.0  Inexistentes  38.0           3     RJ
# 6  1322    Marta     19    F  87.0    Espalhadas  39.0           3     AM
# 7  3027    Paulo     34    M  67.0     Uniformes  38.4           2     GO
# 8  3546  Roberto     44    M   NaN     Uniformes  37.6           1     PE
# 9  6754   Lorena     33    F  72.0  Inexistentes  38.0           3     RJ
#
#         Time Diagnóstico
# 0  Palmeiras      Doente
# 1   Cruzeiro      Doente
# 2     Grêmio    Saudável
# 3   Atlético      Doente
# ...

# %%
display(df.tail(5))
# Out:
#       Id    Nome  Idade Sexo  Peso       Manchas  Temp  Internação Estado  \
# 9   6754  Lorena     33    F  72.0  Inexistentes  38.0           3     RJ
# 10  1735   Pedro     13    M  87.0    Espalhadas   6.0           4     AM
# 11  9834   Laura     65    F   NaN     Uniformes  38.4           2     GO
# 12  4201    João     28    M  79.0  Concentradas  38.0           2     SP
# 13  3217   Maria     18    F  67.0  Inexistentes  39.5           4     MG
#
#          Time Diagnóstico
# 9    Botafogo      Doente
# 10   Flamengo      Doente
# 11  Vila Nova    Saudável
# 12  Palmeiras      Doente
# 13   Cruzeiro    Saudável

# %%
# Agrupar por 'Diagnóstico', mostrando as ocorrências
df.groupby('Diagnóstico').count().plot.pie(y = 'Internação');

# %%
# Qual time tem mais Doentes? :)
df_doente = df[df['Diagnóstico'] == 'Doente']
time_mais_doente = df_doente['Time'].value_counts().idxmax()
print("O time com o maior número de diagnósticos 'Doente' é o",time_mais_doente,"!")
# Out:
# O time com o maior número de diagnósticos 'Doente' é o Palmeiras !
