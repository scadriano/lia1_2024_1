# %% [markdown]
# <a href="https://www.kaggle.com/code/fbioasiqueira/projeto-aula-4?scriptVersionId=169046935" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <hr style="height:10px">
#
# <div class='container2'>
#         <div>
#             <img src= 'data:image/png;base64,...' ALIGN= 'left' style= 'width: 7em'>
#         </div>
#     <div style='padding: 0 7em 2em 12em;'>
#     <h1>Laboratório de Inovação e Automação 1 (LIA 1)</h1>
#     <div style="font-size:12pt;float:left;"> 2024/1 | 24M34 | Sala 200 CAE</b></div><br><br<
#     <div style="font-size:12pt;float:left;"><b>Projetos de Inteligência Artificial</b></div>
#     </div>
# </div>
#
# <hr style="height:5px">
#
# <h2>Introdução ao Ambiente de Projetos - Python</h2>
#
# Notebook desenvolvido por: <a href=""> Fabio Antonio R.S. Siqueira</a>
#
# <hr style "height:2px">

# %%
from platform import python_version
print(f'A versão em uso é {python_version()}.')
# Out:
# A versão em uso é 3.10.13.

# %%
# Verificar se o Python está funcionando
print('Bye bye, World!')
# Out:
# Bye bye, World!

# %%
# Adição
1 + 1
# Out:
# 2

# %%
# Subtração
2 - 1
# Out:
# 1

# %%
# Multiplicação
2 * 2
# Out:
# 4

# %%
# Divisão
3 / 2
# Out:
# 1.5

# %%
# Potência
4 ** 2
# Out:
# 16

# %%
# Módulo (resto da divisão)
10 % 3
# Out:
# 1

# %% [markdown]
# **Tipo de Dados (Type)**

# %%
# Qual o tipo do (?) -> Inteiro
type(5)
# Out:
# int

# %%
# Qual o tipo do (?) -> Float - Decimal
type(5.0)
# Out:
# float

# %%
# Qual o tipo do (?) -> String
a = 'Estudando Python!'
type(a)
# Out:
# str

# %% [markdown]
# **Condicional if**

# %%
# Condicional if (Se)
if 5 > 2:
    print("A sentença é verdadeira!")
# Out:
# A sentença é verdadeira!

# %%
# Condicional if...else
if 5 < 2:
    print("A sentença é verdadeira!")
else:
    print("A sentença é falsa!")
# Out:
# A sentença é falsa!

# %%
# Condicional if...else com variável
dia = "Quarta-feira"
if dia == "Sexta-feira":
    print("Hoje fará sol!")
else:
    print("Hoje vai chover!")
# Out:
# Hoje vai chover!

# %% [markdown]
# **Manipulando arquivos**

# %% [markdown]
# **Lendo arquivos (.txt)**

# %%
# Abrindo o arquivo para leitura
a1 = open("/kaggle/input/arquivo-aula-4-lia-2024-1/arquivo1.txt", "r")

# %%
# Lendo o arquivo
print(a1.read())
# Out:
# Arquivo

# %%
print ("Olá, mundo!")
# Out:
# Olá, mundo!

# %% [markdown]
# # **Escola de Engenharia**

# %% [markdown]
# **Gravando arquivos (.txt**

# %%
# Abrindo o arquivo para gravação
a2 = open("/kaggle/working/arquivo2", "w")

# %%
# Gravando no arquivo
a2.write("Aprendendo Python em 2024/1 ao som de um cortador de grama!")
# Out:
# 59

# %%
# Abrindo o arquivo para leitura
a2 = open("/kaggle/working/arquivo2", "r")

# %%
# Imprimindo arquivo
print(a2.read())
# Out:
# Aprendendo Python em 2024/1 ao som de um cortador de grama!
