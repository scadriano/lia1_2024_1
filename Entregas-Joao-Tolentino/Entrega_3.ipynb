# %% [markdown]
# <a href="https://colab.research.google.com/github/Joao-Tolentino/lia1_2024_1/blob/main/Entregas-Joao-Tolentino/Entrega_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <hr>
# <div class="container">
#     <img src='https://github.com/scadriano/datascience/blob/main/datascienceintroduce/header.png?raw=true' align='left' width='180'  height='200' />
# </div>
#
# <h1>Laboratório de Inovação e Automação 1 (LIA 1)</h1>
# 	<div>  2024/1 | 24M34 | Sala 200 CAE</ </div>
# <hr>
#
# <h2> Introdução ao Python com Github - Colab </h2>
# Notebook desenvolvido por: <a href="http://lattes.cnpq.br/1346824250595330">Prof. Dr. Adriano C. Santana</a>
#
# <hr>

# %%
# Confirmar a versão da Linguagem Python instalada
from platform import python_version
print(f'A versão da linguagem Python usada neste projeto é a {python_version()}!')
#python_version()
# Out:
# A versão da linguagem Python usada neste projeto é a 3.10.12!

# %%
# Verificar se o Python está funcionando
print('Bye bye, World!')
# Out:
# Bye bye, World!

# %% [markdown]
# ## Lendo Arquivos:

# %%
import base64
import requests

# %%
a1 = open("/content/drive/MyDrive/Colab Notebooks/hospital.txt","r")
print(a1.read())
# hospital.txt
# Out:
# Id,Nome,Idade,Sexo,Peso,Manchas,Temp,Internação,Estado,Time,Diagnóstico
# 4201,João,55,M,90,Concentradas,38.0,2,SP,Palmeiras,Doente
# 3217,Maria,56,F,91,Inexistentes,39.5,4,MG,Cruzeiro,Doente
# 4039,Luiz,49,M,92,Espalhadas,38.0,2,RS,Grêmio,Saudável
# 1920,José,57,M,93,Inexistentes,38.5,2,MG,Atlético,Doente
# 4340,Cláudia,21,F,52,Uniformes,37.6,1,PE,Sport,Saudável
# 2301,Ana,58,F,94,Inexistentes,38.0,3,RJ,Botafogo,Doente
# 1322,Marta,19,F,87,Espalhadas,39.0,3,AM,Flamengo,Doente
# 3027,Paulo,34,M,67,Uniformes,38.4,2,GO,Vila Nova,Saudável
# 3546,Roberto,44,M,,Uniformes,37.6,1,PE,Sport,Saudável
# 6754,Lorena,33,F,72,Inexistentes,38.0,3,RJ,Botafogo,Doente
# 1735,Pedro,13,M,87,Espalhadas,6,4,AM,Flamengo,Doente
# 9834,Laura,65,F,,Uniformes,38.4,2,GO,Vila Nova,Saudável
# 4201,João,28,M,79,Concentradas,38.0,2,SP,Palmeiras,Doente
# 3217,Maria,18,F,67,Inexistentes,39.5,4,MG,Cruzeiro,Saudável

# %%
git = "https://raw.githubusercontent.com/scadriano/lia1_2024_1/main/Introdu%C3%A7%C3%A3o%20ao%20Python%20com%20GitHub%20-%20Colab/arquivo1.txt"
req = requests.get(git)
req = req.text
print(req)
# Out:
# Seja bem-vindo em LIA1 - 2024/1 - 01/04!

# %% [markdown]
# ##Escrevendo em Arquivos

# %%
a2 = open("/content/drive/MyDrive/Colab Notebooks/Testin.txt","w")
a2.write("Aprendendo Python 1 - 01/04!")
a2 = open("/content/drive/MyDrive/Colab Notebooks/Testin.txt","r")

# %%
print(a2.read())
# Out:
# Aprendendo Python 1 - 01/04!

# %% [markdown]
# ##Manipulando Datasets

# %%
import pandas as pd
df = pd.read_csv ('https://raw.githubusercontent.com/scadriano/lia1_2024_1/main/Introdu%C3%A7%C3%A3o%20ao%20Python%20com%20GitHub%20-%20Colab/hospital.txt')
df.head()
# Out:
#      Id     Nome  Idade Sexo  Peso       Manchas  Temp  Internação Estado  \
# 0  4201     João     55    M  90.0  Concentradas  38.0           2     SP
# 1  3217    Maria     56    F  91.0  Inexistentes  39.5           4     MG
# 2  4039     Luiz     49    M  92.0    Espalhadas  38.0           2     RS
# 3  1920     José     57    M  93.0  Inexistentes  38.5           2     MG
# 4  4340  Cláudia     21    F  52.0     Uniformes  37.6           1     PE
#
#         Time Diagnóstico
# 0  Palmeiras      Doente
# 1   Cruzeiro      Doente
# 2     Grêmio    Saudável
# 3   Atlético      Doente
# 4      Sport    Saudável

# %%
df
# Out:
#       Id     Nome  Idade Sexo  Peso       Manchas  Temp  Internação Estado  \
# 0   4201     João     55    M  90.0  Concentradas  38.0           2     SP
# 1   3217    Maria     56    F  91.0  Inexistentes  39.5           4     MG
# 2   4039     Luiz     49    M  92.0    Espalhadas  38.0           2     RS
# 3   1920     José     57    M  93.0  Inexistentes  38.5           2     MG
# 4   4340  Cláudia     21    F  52.0     Uniformes  37.6           1     PE
# 5   2301      Ana     58    F  94.0  Inexistentes  38.0           3     RJ
# 6   1322    Marta     19    F  87.0    Espalhadas  39.0           3     AM
# 7   3027    Paulo     34    M  67.0     Uniformes  38.4           2     GO
# 8   3546  Roberto     44    M   NaN     Uniformes  37.6           1     PE
# 9   6754   Lorena     33    F  72.0  Inexistentes  38.0           3     RJ
# 10  1735    Pedro     13    M  87.0    Espalhadas   6.0           4     AM
# ...
