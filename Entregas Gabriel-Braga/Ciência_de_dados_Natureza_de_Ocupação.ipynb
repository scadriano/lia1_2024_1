# %% [markdown]
# <a href="https://colab.research.google.com/github/Bitencourt-hub/lia1_2024_1/blob/main/Entregas%20Gabriel-Braga/Ci%C3%AAncia_de_dados_Natureza_de_Ocupa%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <hr>
# <div class="container">
#     <img src='https://github.com/scadriano/datascience/blob/main/datascienceintroduce/header.png?raw=true' align='left' width='180'  height='200' />
# </div>
#
# <h1>Laboratório de Inovação e Automação 1 (LIA 1)</h1>
# 	<div>  2024/1 | 24M34 | Sala 200 CAE</ </div>
# <hr>
#
# <h2> Ciencia de Dados - Natureza de Ocupação - Colab </h2>
# Notebook desenvolvido por: <a href="http://lattes.cnpq.br/1346824250595330">Prof. Dr. Adriano C. Santana</a>
#
# <hr>

# %% [markdown]
# ## **Ciência de Dados - Natureza de Ocupação Brasileira** 🧢
#
# O dataset a seguir possui comparações entre diferentes naturezas de ocupações de brasilerios entre 2008 e 2002.
#
# **Serão 4 perguntas e 2 desafios! #borafazer**

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %% [markdown]
# **Carregando os dados**

# %%
# Carrega o dataset
df_ss = pd.read_csv('/content/Natureza de Ocupação.csv')

# %%
# Shape
df_ss.shape
# Out:
# (354, 43)

# %%
# Amostra dos dados
df_ss.head()
# Out:
#    Ano-Calendário                               Natureza de Ocupação  \
# 0            2020                 Empregado de empresa setor privado
# 1            2020  Empregado de instituições financeiras públicas...
# 2            2020  Empregado ou contratado de organismo internaci...
# 3            2020  Profissional liberal ou autônomo sem vínculo d...
# 4            2020  Proprietário de empr. ou firma indiv. ou empre...
#
#   Quantidade de Declarantes Rendimentos Tributáveis  \
# 0    exceto instit. financ.                 9807756
# 1                    815541                   81375
# 2                     40881                    2579
# 3                   2065253                   98129
# 4                   4188146                  155000
#
#   Rendimentos sujeitos a Tributação Exclusiva  Rendimentos Isentos  \
# 0                                      583600                 5445
# 1                                       86212                22299
# ...

# %%
# Amostra dos dados
df_ss.tail()
# Out:
#      Ano-Calendário                               Natureza de Ocupação  \
# 349            2008                                           Bolsista
# 350            2008  Adaptação: Bolsista ou beneficiário pensão ali...
# 351            2008                                            Espólio
# 352            2008  Natureza da ocupação não especificada anterior...
# 353            2008                 Microempreendedor Individual - MEI
#
#     Quantidade de Declarantes Rendimentos Tributáveis  \
# 349                     17960                     265
# 350                         5                       0
# 351                    185018                    3148
# 352                    964268                   19828
# 353                     17160                     332
#
#     Rendimentos sujeitos a Tributação Exclusiva  Rendimentos Isentos  \
# 349                                     2974497                   24
# 350                                     6156782                    0
# ...

# %% [markdown]
# **Análise exploratória**

# %%
# Colunas do conjunto de dados
df_ss.columns
# Out:
# Index(['Ano-Calendário', 'Natureza de Ocupação', 'Quantidade de Declarantes',
#        'Rendimentos Tributáveis',
#        'Rendimentos sujeitos a Tributação Exclusiva', 'Rendimentos Isentos',
#        'Dedução Previdenciária Total', 'Deduções Previdência Oficial',
#        'Deduções Previdenciárias RRA', 'Deduções Previdência Privada e FAPI',
#        'Deduções com Dependentes', 'Deduções com Instrução',
#        'Deduções com despesas Médicas', 'Dedução de Livro Caixa',
#        'Deduções  com Pensão Alimentícia Total',
#        'Deduções com Pensão Alimentícia Judicial',
#        'Deduções com Pensão Alimentícia Escritural',
#        'Deduções com Pensão Alimentícia RRA', 'Desconto Padrão',
#        'Base de Cálculo (RTL)', 'Imposto Devido', 'Dedução de Incentivo',
#        'Imposto Devido 1', 'Imposto Devido RRA', 'Imposto Devido Total',
#        'Imposto Pago', 'Imposto a Pagar', 'Imposto a Restituir',
# ...

# %%
# Verificando o tipo de dado de cada coluna
df_ss.dtypes
# Out:
# Ano-Calendário                                                      int64
# Natureza de Ocupação                                               object
# Quantidade de Declarantes                                          object
# Rendimentos Tributáveis                                            object
# Rendimentos sujeitos a Tributação Exclusiva                        object
# Rendimentos Isentos                                                 int64
# Dedução Previdenciária Total                                        int64
# Deduções Previdência Oficial                                      float64
# Deduções Previdenciárias RRA                                      float64
# Deduções Previdência Privada e FAPI                               float64
# Deduções com Dependentes                                          float64
# Deduções com Instrução                                            float64
# Deduções com despesas Médicas                                     float64
# ...

# %%
# Resumo estatístico da coluna com o Imposto Pago
df_ss['Pensão Alimentícia Judicial'].describe()
# Out:
# count    2.920000e+02
# mean     4.154270e+05
# std      3.684159e+06
# min      0.000000e+00
# 25%      2.482500e+02
# 50%      2.962500e+03
# 75%      7.226750e+03
# max      5.213161e+07
# Name: Pensão Alimentícia Judicial, dtype: float64

# %%
# Verificando se há registros duplicados
df_ss[df_ss.duplicated()]
# Out:
# Empty DataFrame
# ...

# %%
# Verificando de há valores ausentes
df_ss.isnull().sum()
# Out:
# Ano-Calendário                                                      0
# Natureza de Ocupação                                                0
# Quantidade de Declarantes                                           0
# Rendimentos Tributáveis                                             0
# Rendimentos sujeitos a Tributação Exclusiva                         0
# Rendimentos Isentos                                                 0
# Dedução Previdenciária Total                                        0
# Deduções Previdência Oficial                                        2
# Deduções Previdenciárias RRA                                        2
# Deduções Previdência Privada e FAPI                                 2
# Deduções com Dependentes                                            2
# Deduções com Instrução                                            172
# Deduções com despesas Médicas                                     218
# ...

# %% [markdown]
# ## **1. Qual a média de arrecadação de imposto de um militar?**

# %%
# Primeiro filtramos o dataframe com os registros da categoria que desejamos
df_ss_p1 = df_ss[df_ss['Natureza de Ocupação'] == 'Militar']

# %%
# Em seguida agrupamos por ano e calculamos o total de arrecadação
df_ss_p1_total = df_ss_p1.groupby('Ano-Calendário')['Imposto Pago'].sum()

# %%
# Calcula a média de imposto pago de um militar
media_investimentos_tributaveis = df_ss_p1.groupby('Ano-Calendário')['Imposto Pago'].mean()

# Imprime a média
print("Média de imposto pago por militar:")
print(media_investimentos_tributaveis)
# Out:
# Média de imposto pago por militar:
# Ano-Calendário
# 2008       NaN
# 2009       NaN
# 2010       NaN
# 2011       NaN
# 2012       NaN
# 2013       NaN
# 2014       NaN
# 2015       NaN
# 2016    1520.0
# 2017    1544.0
# 2018    1591.0
# 2019    1627.0
# 2020    1665.0
# Name: Imposto Pago, dtype: float64

# %%
# Para conferir o resultado
df_ss_p1_total.sort_values(ascending = False)
# Out:
# Ano-Calendário
# 2020    1665.0
# 2019    1627.0
# 2018    1591.0
# 2017    1544.0
# 2016    1520.0
# 2008       0.0
# 2009       0.0
# 2010       0.0
# 2011       0.0
# 2012       0.0
# 2013       0.0
# 2014       0.0
# 2015       0.0
# Name: Imposto Pago, dtype: float64

# %% [markdown]
# ## **2. Qual o aumento, percentual, de trabalhadores MEI/Autônomos 2008 até 2020?**
# Apresente o resultado em um gráfico de barras.

# %%
# Convertendo a coluna 'Quantidade de Declarantes' para o tipo numérico
df_ss['Quantidade de Declarantes'] = pd.to_numeric(df_ss['Quantidade de Declarantes'], errors='coerce')

# Calculando o total de trabalhadores MEI/Autônomos para cada ano
df_ss_p2 = df_ss.groupby('Ano-Calendário')['Quantidade de Declarantes'].sum()

# Calculando o aumento percentual em relação ao ano anterior
aumento_percentual = df_ss_p2.pct_change() * 100

# %%
df_ss_p2.head()
# Out:
# Ano-Calendário
# 2008    16034560.0
# 2009    15257819.0
# 2010    14912641.0
# 2011    15499316.0
# 2012    16179140.0
# Name: Quantidade de Declarantes, dtype: float64

# %%
# Plotando o gráfico de barras
plt.figure(figsize=(12, 6))
aumento_percentual[1:].plot(kind='bar', color='blue')
plt.title('Aumento Percentual de Trabalhadores MEI/Autônomos (2009-2020)')
plt.xlabel('Ano-Calendário')
plt.ylabel('Aumento Percentual')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## **3. Qual é a distribuição dos rendimentos tributáveis para diferentes categorias ocupacionais em 2020 e qual categoria apresentou a maior média de rendimentos tributáveis?**

# %%
# Removendo caracteres não numéricos da coluna 'Rendimentos Tributáveis'
df_ss['Rendimentos Tributáveis'] = df_ss['Rendimentos Tributáveis'].str.replace(r'\D', '', regex=True)

# Convertendo os valores para float, e tratando valores vazios ou nulos como NaN
df_ss['Rendimentos Tributáveis'] = pd.to_numeric(df_ss['Rendimentos Tributáveis'], errors='coerce')

# Filtrando os dados para o ano de 2020
df_2020 = df_ss[df_ss['Ano-Calendário'] == 2020]

# %%
# Agrupando os dados pela coluna 'Natureza de Ocupação' e calculando a média dos rendimentos tributáveis
media_rendimentos = df_2020.groupby('Natureza de Ocupação')['Rendimentos Tributáveis'].mean()

# Identificando a categoria com a maior média de rendimentos tributáveis
categoria_maior_media = media_rendimentos.idxmax()
maior_media = media_rendimentos.max()

# %%
# Imprimindo a categoria com a maior média de rendimentos tributáveis
print("A categoria com a maior média de rendimentos tributáveis em 2020 é:", categoria_maior_media)
print("Média de rendimentos tributáveis:", maior_media)
# Out:
# A categoria com a maior média de rendimentos tributáveis em 2020 é: Empregado de empresa setor privado
# Média de rendimentos tributáveis: 9807756.0

# %%
# Filtrando os dados para o ano de 2020
df_2020 = df_ss[df_ss['Ano-Calendário'] == 2020]

# Agrupando os dados pela coluna 'Natureza de Ocupação' e calculando a média dos rendimentos tributáveis
media_rendimentos = df_2020.groupby('Natureza de Ocupação')['Rendimentos Tributáveis'].mean()

# Plotando o gráfico de barras
plt.figure(figsize=(12, 6))
media_rendimentos.plot(kind='bar', color='skyblue')
plt.title('Média dos Rendimentos Tributáveis por Categoria Ocupacional (2020)')
plt.xlabel('Categoria Ocupacional')
plt.ylabel('Média dos Rendimentos Tributáveis')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Desafio 1 - Nível Júnior**
#
# Crie uma projeção para 2050 dos custos com despesas médicas dos aposentados, baseando-se nos custos de 2016 até 2020.

# %%
# Filtrando os dados para considerar apenas as despesas médicas de pessoas aposentadas e os anos de 2016 até 2020
df_aposentados = df_ss[df_ss['Natureza de Ocupação'] == 'Aposentado']
despesas_medicas_aposentados_2016_2020 = df_aposentados[df_aposentados['Ano-Calendário'].between(2016, 2020)].groupby('Ano-Calendário')['Despesas Médicas'].sum()

# %%
# Calculando a taxa de crescimento anual média das despesas médicas para o período de 2016 a 2020
taxa_crescimento_anual = despesas_medicas_aposentados_2016_2020.pct_change().mean()

# Projeto das despesas médicas para 2050 com base na taxa de crescimento média
despesas_medicas_2050 = despesas_medicas_aposentados_2016_2020.iloc[-1] * (1 + taxa_crescimento_anual) ** (2050 - despesas_medicas_aposentados_2016_2020.index[-1])

# %%
# Valor inicial (despesas médicas de 2016)
valor_inicial = despesas_medicas_aposentados_2016_2020.iloc[0]

# Valor final (despesas médicas de 2020)
valor_final = despesas_medicas_aposentados_2016_2020.iloc[-1]

# Calculando o crescimento percentual
crescimento_percentual = ((valor_final - valor_inicial) / valor_inicial) * 100

print("Crescimento percentual das despesas médicas de 2016 até 2020:", crescimento_percentual, "%")
# Out:
# Crescimento percentual das despesas médicas de 2016 até 2020: 25.18948286270038 %

# %%
# Plotando o gráfico da projeção das despesas médicas
plt.figure(figsize=(10, 6))
plt.plot(despesas_medicas_aposentados_2016_2020.index, despesas_medicas_aposentados_2016_2020.values, marker='o', linestyle='-', color='b', label='Despesas Médicas de Aposentados (2016-2020)')
plt.plot(2050, despesas_medicas_2050, marker='o', markersize=8, color='r', label='Projeção para 2050')
plt.title('Projeção das Despesas Médicas de Aposentados até 2050')
plt.xlabel('Ano')
plt.ylabel('Despesas Médicas')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## **Desafio 2 - Nível Master**
#
# Faça uma comparação entre o nivel de contribuição arrecadado de todos os tipos de Ocupação

# %%
# Primeiro, vamos calcular a média de imposto a pagar para cada natureza de ocupação
media_por_ocupacao = df_ss.groupby('Natureza de Ocupação')['Imposto a Pagar'].mean()

# Agora, vamos agrupar os dados por ano e por natureza de ocupação e calcular a média de imposto a pagar
media_por_ano_ocupacao = df_ss.groupby(['Ano-Calendário', 'Natureza de Ocupação'])['Imposto a Pagar'].mean().unstack()

# %%
# Agora, vamos plotar o gráfico
media_por_ano_ocupacao.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Média de Imposto a Pagar por Ano e Natureza de Ocupação')
plt.xlabel('Ano-Calendário')
plt.ylabel('Média de Imposto a Pagar')
plt.legend(title='Natureza de Ocupação', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Desafio 4 - Nível Master Ninja das Galáxias**
#
# Qual o total de vendas por categoria e subcategoria, considerando somente as Top 12 subcategorias?
#
# Apresente tudo em um único gráfico.

# %%
df_ss.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda   Ano  Desconto  Valor_Venda_Desconto  Mes
# ...

# %%
# Agrupamos por categoria e subcategoria e calculamos a soma somente para variáveus numéricas
df_ss_d4 = df_ss.groupby(['Categoria',
                             'SubCategoria']).sum(numeric_only = True).sort_values('Valor_Venda',
                                                                                   ascending = False).head(12)

# %%
# Convertemos a coluna Valor_Venda em número inteiro e classificamos por categoria
df_ss_d4 = df_ss_d4[['Valor_Venda']].astype(int).sort_values(by = 'Categoria').reset_index()

# %% [markdown]
# Obs: Classificar o item acima por categoria é importante para preencher o gráfico com as subcategorias para cada categoria de forma ordenada.

# %%
# Dataframe com categorias e subcategorias
df_ss_d4
# Out:
#           Categoria SubCategoria  Valor_Venda
# 0         Furniture       Chairs       317919
# 1         Furniture       Tables       202083
# 2         Furniture    Bookcases       108045
# 3         Furniture  Furnishings        88862
# 4   Office Supplies      Storage       216188
# 5   Office Supplies      Binders       194723
# 6   Office Supplies   Appliances       104061
# 7   Office Supplies        Paper        76312
# 8        Technology       Phones       325271
# 9        Technology     Machines       189238
# 10       Technology  Accessories       162791
# 11       Technology      Copiers       146248

# %%
# Criamos outro dataframe somente com os totais por categoria
df_ss_d4_cat = df_ss_d4.groupby('Categoria').sum(numeric_only = True).reset_index()

# %%
# Dataframe com categorias
df_ss_d4_cat
# Out:
#          Categoria  Valor_Venda
# 0        Furniture       716909
# 1  Office Supplies       591284
# 2       Technology       823548

# %%
# Listas de cores para categorias
cores_categorias = ['#5d00de',
                    '#0ee84f',
                    '#e80e27']

# %%
# Listas de cores para subcategorias
cores_subcategorias = ['#aa8cd4',
                       '#aa8cd5',
                       '#aa8cd6',
                       '#aa8cd7',
                       '#26c957',
                       '#26c958',
                       '#26c959',
                       '#26c960',
                       '#e65e65',
                       '#e65e66',
                       '#e65e67',
                       '#e65e68']

# %%
# Plot

# Tamanho da figura
fig, ax = plt.subplots(figsize = (18,12))

# Gráfico das categorias
p1 = ax.pie(df_ss_d4_cat['Valor_Venda'],
            radius = 1,
            labels = df_ss_d4_cat['Categoria'],
            wedgeprops = dict(edgecolor = 'white'),
            colors = cores_categorias)

# Gráfico das subcategorias
p2 = ax.pie(df_ss_d4['Valor_Venda'],
            radius = 0.9,
            labels = df_ss_d4['SubCategoria'],
            autopct = autopct_format(df_ss_d4['Valor_Venda']),
            colors = cores_subcategorias,
            labeldistance = 0.7,
            wedgeprops = dict(edgecolor = 'white'),
            pctdistance = 0.53,
            rotatelabels = True)

# Limpa o centro do círculo
centre_circle = plt.Circle((0, 0), 0.6, fc = 'white')

# Labels e anotações
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.annotate(text = 'Total de Vendas: ' + '$ ' + str(int(sum(df_ss_d4['Valor_Venda']))), xy = (-0.2, 0))
plt.title('Total de Vendas Por Categoria e Top 12 SubCategorias')
plt.show()

# %% [markdown]
# ## **Fim**
